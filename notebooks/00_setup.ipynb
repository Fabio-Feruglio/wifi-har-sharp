# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabio-Feruglio/wifi-har-sharp/blob/main/notebooks/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cella 1: monta Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cella 2: clona il repo GitHub (prima volta)
# Sostituisci con il tuo username e nome repo
# !git clone https://github.com/Fabio-Feruglio/wifi-har-sharp.git /content/wifi-har-sharp

# Oppure se il repo è già clonato, aggiorna solo (sessioni successive)
# %cd /content/wifi-har-sharp
# !git pull
# Out:
# Cloning into '/content/wifi-har-sharp'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (50/50), done.
# Receiving objects: 100% (55/55), 18.22 KiB | 6.07 MiB/s, done.
# remote: Total 55 (delta 24), reused 0 (delta 0), pack-reused 0 (from 0)
# Resolving deltas: 100% (24/24), done.

# %%
# Cella 3: installa le dipendenze
# !pip install -q wandb torchmetrics pyyaml tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 26.4 MB/s eta 0:00:00

# %%
# Cella 4: crea symlink tra cartella dati su Drive e cartella nel repo
import os
os.makedirs('/content/wifi-har-sharp/data/raw', exist_ok=True)
os.makedirs('/content/wifi-har-sharp/data/processed', exist_ok=True)
os.makedirs('/content/wifi-har-sharp/results', exist_ok=True)

# !ln -sfn /content/drive/MyDrive/sharp_project/data/raw \
          /content/wifi-har-sharp/data/raw

# !ln -sfn /content/drive/MyDrive/sharp_project/data/processed \
          /content/wifi-har-sharp/data/processed

# !ln -sfn /content/drive/MyDrive/sharp_project/results \
          /content/wifi-har-sharp/results

# %%
# Cella 5: aggiungi src/ al Python path
import sys
sys.path.insert(0, '/content/wifi-har-sharp/src')

print("Setup completato!")
# Out:
# Setup completato!

# %%
# Cella finale di ogni notebook: salva su GitHub
import os

# Prima salvi il notebook su Drive come backup
from google.colab import runtime

# %cd /content/wifi-har-sharp

# Configura git (solo la prima volta per sessione)
# !git config user.email "tua@email.com"
# !git config user.name "TuoNome"

# Aggiungi solo i file .py e .ipynb, non i dati
# !git add src/ notebooks/ configs/
# !git commit -m "Update da Colab: descrivi cosa hai fatto"

# Per il push serve il token: vai su GitHub → Settings →
# Developer Settings → Personal Access Token → genera uno
# e usalo al posto della password
# !git push https://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@github.com/Fabio-Feruglio/wifi-har-sharp.git main
